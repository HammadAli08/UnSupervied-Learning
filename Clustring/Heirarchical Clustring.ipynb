# %% [markdown]
# # This is used for Linearly Separable Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from PIL.ImageColor import colormap

data1=pd.read_csv("/home/hammadali08/Vidoes/CSV file/iris.csv")

# %% [markdown]
# # Agglomertive CLustring

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/iris.csv")
data.drop(columns=['species'],inplace=True)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(figsize=(20,15))
sch.dendrogram(sch.linkage(data,method='average',metric='euclidean'))
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Euclidean Distance')
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
ac=AgglomerativeClustering(n_clusters=2,linkage='complete')

# %%
data['Predict']=(ac.fit_predict(data))
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Predict
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        1
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        1
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data,hue='Predict',x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.pairplot(data,hue='Predict',palette='Set2')
plt.show()
