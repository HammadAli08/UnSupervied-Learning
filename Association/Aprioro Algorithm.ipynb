# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv('/home/hammadali08/Vidoes/CSV file/association example.csv')
data=data.head(10000)
data
# Out:
#      Item(s)            Item 1               Item 2            Item 3  \
# 0          4      citrus fruit  semi-finished bread         margarine
# 1          3    tropical fruit               yogurt            coffee
# 2          1        whole milk                  NaN               NaN
# 3          4         pip fruit               yogurt      cream cheese
# 4          4  other vegetables           whole milk    condensed milk
# ..       ...               ...                  ...               ...
# 995        3  other vegetables   whipped/sour cream     roll products
# 996       23           chicken       tropical fruit         pip fruit
# 997        1         ice cream                  NaN               NaN
# 998        5              pork                 beef         ice cream
# 999       10              pork       tropical fruit  other vegetables
#
#                        Item 4               Item 5        Item 16   Item 17  \
# ...

# %%
market=[]
for i in range(0,data.shape[0]):
    customer=[]
    for j in data.columns:
        if type(data[j][i])==str:
            customer.append(data[j][i])
    market.append(customer)

# %%
market
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit', 'tropical fruit', 'whole milk', 'butter', 'curd'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
# ...

# %%
l=[]
for i in market:
    for j in i:
        l.append(j)

# %%
import collections
c=collections.Counter(l)
c
# Out:
# Counter({'whole milk': 255,
#          'rolls/buns': 183,
#          'other vegetables': 180,
#          'soda': 117,
#          'yogurt': 109,
#          'root vegetables': 109,
#          'tropical fruit': 97,
#          'citrus fruit': 95,
#          'bottled water': 94,
#          'sausage': 78,
#          'frankfurter': 73,
#          'curd': 69,
#          'beef': 69,
#          'canned beer': 67,
#          'pastry': 60,
#          'bottled beer': 54,
#          'newspapers': 53,
#          'pork': 53,
#          'whipped/sour cream': 53,
#          'coffee': 49,
#          'berries': 47,
#          'pip fruit': 41,
#          'domestic eggs': 40,
#          'butter': 37,
#          'hamburger meat': 37,
#          'fruit/vegetable juice': 36,
#          'brown bread': 35,
#          'shopping bags': 35,
#          'onions': 33,
#          'chicken': 32,
#          'margarine': 31,
#          'frozen vegetables': 31,
#          'cream cheese': 30,
# ...

# %%
df=pd.DataFrame({'List names':c.keys(),'Count':c.values()})
df.sort_values(by='Count',ascending=False,inplace=True)
df
# Out:
#            List names  Count
# 7          whole milk    255
# 17         rolls/buns    183
# 11   other vegetables    180
# 29               soda    117
# 5              yogurt    109
# ..                ...    ...
# 122          cookware      1
# 133         nut snack      1
# 97       cocoa drinks      1
# 125  bathroom cleaner      1
# 101          prosecco      1
#
# [153 rows x 2 columns]

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr=TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df1=pd.DataFrame(tr.transform(market),columns=tr.columns_)
df1
# Out:
#      Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                    False     False             False             False
# 1                    False     False             False             False
# 2                    False     False             False             False
# 3                    False     False             False             False
# 4                    False     False             False             False
# ..                     ...       ...               ...               ...
# 995                  False     False             False             False
# 996                  False     False             False             False
# 997                  False     False             False             False
# 998                  False     False             False             False
# 999                  False     False             False             False
#
#      baking powder  bathroom cleaner   beef  berries  beverages  bottled beer  \
# ...

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori_df=(apriori(df1,min_support=0.01,use_colnames=True,max_len=4)).sort_values('support')
apriori_df
# Out:
#      support                     itemsets
# 102    0.010  (domestic eggs, rolls/buns)
# 65     0.010              (berries, beef)
# 51     0.010        (semi-finished bread)
# 76     0.010      (beverages, whole milk)
# 43     0.010                 (photo/film)
# ..       ...                          ...
# 48     0.109            (root vegetables)
# 54     0.117                       (soda)
# 40     0.180           (other vegetables)
# 47     0.183                 (rolls/buns)
# 63     0.255                 (whole milk)
#
# [157 rows x 2 columns]
