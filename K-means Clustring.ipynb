# %% [markdown]
# # This is used for Linearly Separable DataSet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL.ImageColor import colormap

data1=pd.read_csv("/home/hammadali08/Vidoes/CSV file/iris.csv")

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/iris.csv")
data.drop(columns=['species'],inplace=True)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.pairplot(data)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]
for i in range(1,20):
    km=KMeans(n_clusters=i)
    km.fit(data)
    wcss.append(km.inertia_)

# %%
plt.figure(figsize=(10,6))
plt.plot([i for i in range(1,20)],wcss,marker="o")
plt.title("The elbow method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.grid(axis="x")
plt.xticks([i for i in range(1,20)])
plt.show()

# %%
km=KMeans(n_clusters=3)
data['Predict']=km.fit_predict(data)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Predict
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data,hue="Predict")
plt.savefig("/home/hammadali08/Vidoes/CSV file/iris.png")
plt.show()

# %%
sns.pairplot(data1,hue="species",palette="Set2")
plt.savefig("/home/hammadali08/Vidoes/CSV file/iris11.png")
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(data,data['Predict'])
# Out:
# 0.6229490014131421

# %%
ss=[]
for i in range(2,20):
     km=KMeans(n_clusters=i)
     km.fit_predict(data)
     ss.append(silhouette_score(data,km.labels_))

# %%
plt.bar([i for i in range(2,20)],ss)
plt.grid(axis='x')
plt.xticks([i for i in range(2,20)])
plt.show()

# %%
plt.plot([i for i in range(2,20)],ss,marker="o")
plt.title("Sihlouette Score")
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette Scores")
plt.xticks([i for i in range(2,20)])
plt.grid(axis="y")
plt.show()
