# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.datasets import  make_moons

# %%
x,y=make_moons(n_samples=300,noise=0.05)

# %%
df=pd.DataFrame({'x':x[:,0],'y':x[:,1],'Output':y})
df
# Out:
#             x         y  Output
# 0   -0.640249  0.756325       0
# 1    1.977426  0.273650       1
# 2   -0.206898  1.091046       0
# 3    0.029304  0.319293       1
# 4    0.199322 -0.021778       1
# ..        ...       ...     ...
# 295 -0.892499  0.185532       0
# 296 -0.369486  0.874779       0
# 297  1.875610 -0.190026       1
# 298  0.457373  0.861961       0
# 299  1.966847  0.378891       1
#
# [300 rows x 3 columns]

# %%
sns.scatterplot(x='x',y='y',hue='Output',data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
db=DBSCAN(eps=0.2,min_samples=2,metric = "euclidean")

# %%
df['Predict']=db.fit_predict(x)
df
# Out:
#             x         y  Output  Predict
# 0   -0.640249  0.756325       0        0
# 1    1.977426  0.273650       1        1
# 2   -0.206898  1.091046       0        0
# 3    0.029304  0.319293       1        1
# 4    0.199322 -0.021778       1        1
# ..        ...       ...     ...      ...
# 295 -0.892499  0.185532       0        0
# 296 -0.369486  0.874779       0        0
# 297  1.875610 -0.190026       1        1
# 298  0.457373  0.861961       0        0
# 299  1.966847  0.378891       1        1
#
# [300 rows x 4 columns]

# %%
scatter_plot=sns.scatterplot(x='x',y='y',hue='Predict',data=df)
