# %%
import pandas as pd
from sklearn.datasets import make_moons

# %% [markdown]
# # For Classification Data

# %%
x,y=make_moons(n_samples=1000,noise=0.7)
df=pd.DataFrame({'x1':x[:,0],'x2':x[:,1],'y':y})
df
# Out:
#            x1        x2  y
# 0   -1.543666  0.061381  0
# 1    0.763235 -0.153732  1
# 2   -1.103100  1.516496  0
# 3   -0.036513  1.016706  0
# 4   -0.325456  0.658378  0
# ..        ...       ... ..
# 995  1.462095 -0.178073  1
# 996 -0.494688  1.173960  0
# 997 -2.309889 -0.304700  0
# 998  0.997184 -0.141695  1
# 999  0.422015  1.390199  0
#
# [1000 rows x 3 columns]

# %%
x_a=df.iloc[:,:-1]
y_a=df['y']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_a,y_a,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC

# %%
bc=BaggingClassifier(estimator=SVC(),n_estimators=10)

# %%
bc.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC())

# %%
bc.score(x_train,y_train),bc.score(x_test,y_test)
# Out:
# (0.79125, 0.795)

# %% [markdown]
# # For Regression Data

# %%
data=pd.read_csv("/home/hammadali08/Vidoes/CSV file/Salary Data.csv")
data.drop(columns=['Age','Gender','Education Level','Job Title'],inplace=True)
data.dropna(inplace=True)
data
# Out:
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [373 rows x 2 columns]

# %%
x=data.iloc[:,:-1]
y=data['Salary']
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import LinearRegression

# %%
br=BaggingRegressor(estimator=LinearRegression(),n_estimators=50)
br.fit(x_train,y_train)
# Out:
# BaggingRegressor(estimator=LinearRegression(), n_estimators=50)

# %%
br.score(x_train,y_train),br.score(x_test,y_test)
# Out:
# (0.8563555874374806, 0.8999094935194835)
